# %%
import os
import cv2
from ultralytics import YOLO

# Load YOLOv8 model
model = YOLO('runs/detect/beer5/weights/best.pt')

# Đường dẫn đến thư mục chứa các ảnh
image_folder = 'dataset/val'
# Đường dẫn đến thư mục lưu kết quả
base_output_dir = 'output_knn/val'

# Hàm để tạo thư mục nếu chưa tồn tại
def create_dir_if_not_exists(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)

# Tạo thư mục chính để lưu ảnh crop
create_dir_if_not_exists(base_output_dir)

# Duyệt qua từng file trong thư mục ảnh
for image_filename in os.listdir(image_folder):
    if image_filename.endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff')):
        image_path = os.path.join(image_folder, image_filename)
        
        # Đọc ảnh
        image = cv2.imread(image_path)
        
        # Chạy detection trên ảnh
        results = model(image, conf=0.25)
        
        # Lấy các thông tin của các bounding boxes
        for result in results:
            boxes = result.boxes.xyxy.cpu().numpy()
            classes = result.boxes.cls.cpu().numpy()
            scores = result.boxes.conf.cpu().numpy()
            
            for i, (box, cls, score) in enumerate(zip(boxes, classes, scores)):
                class_name = model.names[int(cls)]
                x1, y1, x2, y2 = map(int, box)
                
                # Tạo thư mục cho từng class
                class_dir = os.path.join(base_output_dir, class_name)
                create_dir_if_not_exists(class_dir)
                
                # Crop ảnh
                crop_img = image[y1:y2, x1:x2]
                
                # Đặt tên file với định dạng ảnh_tên_lớp_i.jpg
                existing_files = os.listdir(class_dir)
                next_index = len(existing_files) + 1
                crop_img_filename = os.path.join(class_dir, f"{os.path.splitext(image_filename)[0]}_{next_index}.jpg")
                
                # Lưu ảnh crop
                cv2.imwrite(crop_img_filename, crop_img)

print("Hoàn thành việc crop và lưu ảnh.")
# Out:
# 0: 640x480 4 Heinekens, 3 Tigers, 1 Bia_Viet, 9.4ms
# Speed: 1.5ms preprocess, 9.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x512 1 Bia_Viet, 8.1ms
# Speed: 1.8ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x640 2 Bia_Viets, 8.4ms
# Speed: 1.8ms preprocess, 8.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 Sai_gons, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 7.7ms
# Speed: 1.7ms preprocess, 7.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 2 Sai_gons, 7.7ms
# Speed: 1.3ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 3 Tigers, 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 1 Tiger, 7.4ms
# Speed: 1.9ms preprocess, 7.4ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x640 8 Tigers, 3 Strongbows, 4 Sai_gons, 8.4ms
# Speed: 1.4ms preprocess, 8.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x480 3 Tigers, 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 1 Tiger, 2 Larues, 1 Huda, 7.6ms
# Speed: 1.2ms preprocess, 7.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x640 1 bia_333, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Strongbow, 7.8ms
# Speed: 2.0ms preprocess, 7.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 Huda, 8.3ms
# Speed: 1.3ms preprocess, 8.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 Tiger, 9.2ms
# Speed: 2.2ms preprocess, 9.2ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x640 1 bia_333, 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x480 4 Tigers, 8.2ms
# Speed: 1.7ms preprocess, 8.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x448 2 Sai_gons, 8.3ms
# Speed: 1.2ms preprocess, 8.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 640x640 4 Strongbows, 8.1ms
# Speed: 1.8ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 2 bia_333s, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 1 Tiger, 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x640 1 bia_333, 8.2ms
# Speed: 1.7ms preprocess, 8.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 8.4ms
# Speed: 1.7ms preprocess, 8.4ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Bia_Viets, 7.8ms
# Speed: 1.3ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 2 Strongbows, 8.1ms
# Speed: 1.9ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Tiger, 7.8ms
# Speed: 1.6ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Sai_gon, 8.3ms
# Speed: 1.3ms preprocess, 8.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 416x640 1 Tiger, 8.2ms
# Speed: 1.2ms preprocess, 8.2ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 480x640 (no detections), 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 544x640 2 Sai_gons, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 448x640 1 Heineken, 8.1ms
# Speed: 1.3ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 11 Sai_gons, 7.6ms
# Speed: 1.3ms preprocess, 7.6ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 4 Heinekens, 8.8ms
# Speed: 1.7ms preprocess, 8.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 2 Sai_gons, 8.8ms
# Speed: 1.5ms preprocess, 8.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 Sai_gons, 7.7ms
# Speed: 1.8ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 Tigers, 7.7ms
# Speed: 1.6ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Sai_gon, 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.6ms
# Speed: 1.7ms preprocess, 7.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x320 (no detections), 8.0ms
# Speed: 1.3ms preprocess, 8.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 320)
#
# 0: 640x640 4 Sai_gons, 8.1ms
# Speed: 1.8ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 Heineken, 1 Bia_Viet, 1 Sai_gon, 7.9ms
# Speed: 1.0ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 Heinekens, 8.0ms
# Speed: 1.7ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 (no detections), 8.3ms
# Speed: 1.0ms preprocess, 8.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 28 Heinekens, 96 Tigers, 15 Bia_Viets, 8.3ms
# Speed: 1.9ms preprocess, 8.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 Heinekens, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 Sai_gon, 7.9ms
# Speed: 1.7ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 6 bia_333s, 8.0ms
# Speed: 1.7ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 512x640 2 bia_333s, 8.7ms
# Speed: 1.2ms preprocess, 8.7ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x640 1 bia_333, 8.9ms
# Speed: 1.6ms preprocess, 8.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x480 3 Bia_Viets, 7.9ms
# Speed: 1.7ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 480x640 1 Bia_Viet, 8.3ms
# Speed: 1.7ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Heinekens, 3 Tigers, 7.8ms
# Speed: 1.7ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x480 4 Heinekens, 8.5ms
# Speed: 1.3ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 480x640 2 bia_333s, 8.9ms
# Speed: 1.1ms preprocess, 8.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x480 21 Tigers, 12 Bia_Viets, 7.9ms
# Speed: 1.6ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 448x640 3 Tigers, 8.6ms
# Speed: 1.2ms preprocess, 8.6ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 bia_333, 4 Hudas, 8.5ms
# Speed: 1.3ms preprocess, 8.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 352x640 2 bia_333s, 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 640x640 1 Sai_gon, 8.8ms
# Speed: 1.6ms preprocess, 8.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 448x640 12 Tigers, 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 3 Strongbows, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 (no detections), 7.9ms
# Speed: 1.1ms preprocess, 7.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Heineken, 3 Tigers, 7.6ms
# Speed: 1.1ms preprocess, 7.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x512 1 Heineken, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x640 1 bia_333, 8.7ms
# Speed: 1.6ms preprocess, 8.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x384 3 Larues, 7.9ms
# Speed: 1.1ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 480x640 1 bia_333, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x416 1 Sai_gon, 8.1ms
# Speed: 1.1ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 640x416 1 Sai_gon, 7.7ms
# Speed: 1.0ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 448x640 4 bia_333s, 8.0ms
# Speed: 1.3ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x640 1 bia_333, 7.9ms
# Speed: 1.3ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x480 7 Heinekens, 1 Tiger, 1 Bia_Viet, 8.2ms
# Speed: 1.7ms preprocess, 8.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 480x640 (no detections), 7.9ms
# Speed: 1.5ms preprocess, 7.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x480 106 Tigers, 8.2ms
# Speed: 1.3ms preprocess, 8.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 448x640 1 Sai_gon, 8.1ms
# Speed: 1.3ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 (no detections), 7.9ms
# Speed: 1.3ms preprocess, 7.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x480 (no detections), 7.9ms
# Speed: 1.3ms preprocess, 7.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 480)
# libpng warning: iCCP: known incorrect sRGB profile
# 0: 480x640 3 Tigers, 1 Sai_gon, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 4 bia_333s, 7.8ms
# Speed: 1.7ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x480 (no detections), 7.9ms
# Speed: 1.3ms preprocess, 7.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 480x640 (no detections), 8.6ms
# Speed: 1.3ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Tigers, 7.9ms
# Speed: 1.2ms preprocess, 7.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x480 2 Bia_Viets, 4 Sai_gons, 7.7ms
# Speed: 1.7ms preprocess, 7.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 448x640 5 Tigers, 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x640 4 bia_333s, 8.3ms
# Speed: 1.9ms preprocess, 8.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x480 1 Sai_gon, 2 Hudas, 8.6ms
# Speed: 1.7ms preprocess, 8.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 3 Tigers, 1 Huda, 7.5ms
# Speed: 1.8ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 480x640 (no detections), 7.8ms
# Speed: 1.3ms preprocess, 7.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 448x640 2 Tigers, 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x480 4 Heinekens, 7 Tigers, 9 Strongbows, 7.7ms
# Speed: 1.7ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 2 Bia_Viets, 1 Sai_gon, 8.0ms
# Speed: 1.3ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x640 1 Sai_gon, 8.4ms
# Speed: 1.4ms preprocess, 8.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 1 bia_333, 8.1ms
# Speed: 1.7ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 480x640 1 Sai_gon, 7.8ms
# Speed: 1.5ms preprocess, 7.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x480 (no detections), 8.3ms
# Speed: 1.3ms preprocess, 8.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x480 5 Heinekens, 2 Tigers, 1 Bia_Viet, 2 Larues, 2 Edelweisss, 2 Strongbows, 11 Sai_gons, 2 bia_333s, 2 Hudas, 8.1ms
# Speed: 1.7ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x640 1 bia_333, 8.8ms
# Speed: 1.6ms preprocess, 8.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x480 (no detections), 7.9ms
# Speed: 1.9ms preprocess, 7.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 416x640 1 Heineken, 8.7ms
# Speed: 1.2ms preprocess, 8.7ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x640 6 Tigers, 2 Strongbows, 7.8ms
# Speed: 2.1ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 512x640 7 Tigers, 7.7ms
# Speed: 1.4ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 480x640 1 Sai_gon, 8.3ms
# Speed: 1.4ms preprocess, 8.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 1 Heineken, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 448x640 5 Tigers, 8.8ms
# Speed: 1.7ms preprocess, 8.8ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x480 3 Tigers, 3 Sai_gons, 7.8ms
# Speed: 1.5ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 544x640 2 Sai_gons, 7.8ms
# Speed: 1.4ms preprocess, 7.8ms inference, 1.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 4 Heinekens, 1 Strongbow, 7.7ms
# Speed: 1.3ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 4 bia_333s, 7.8ms
# Speed: 1.4ms preprocess, 7.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 3 bia_333s, 8.7ms
# Speed: 1.6ms preprocess, 8.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 bia_333, 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 352x640 3 Heinekens, 4 Tigers, 3 Larues, 1 Edelweiss, 1 Strongbow, 7.7ms
# Speed: 0.9ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
# libpng warning: iCCP: known incorrect sRGB profile
# 0: 448x640 7 Tigers, 8.1ms
# Speed: 1.8ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 9 Sai_gons, 3 bia_333s, 8.4ms
# Speed: 1.1ms preprocess, 8.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x480 1 Heineken, 1 Tiger, 7.7ms
# Speed: 2.2ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x416 18 Tigers, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 416x640 2 Heinekens, 7.8ms
# Speed: 1.2ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 480x640 (no detections), 7.7ms
# Speed: 1.3ms preprocess, 7.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Sai_gon, 7.4ms
# Speed: 1.4ms preprocess, 7.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 1 bia_333, 7.8ms
# Speed: 1.4ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x480 (no detections), 8.7ms
# Speed: 1.4ms preprocess, 8.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x640 1 Strongbow, 8.7ms
# Speed: 1.5ms preprocess, 8.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 bia_333, 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 4 Strongbows, 7.7ms
# Speed: 0.8ms preprocess, 7.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 bia_333, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 Strongbow, 7.7ms
# Speed: 1.6ms preprocess, 7.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 1 Strongbow, 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 Heineken, 7.5ms
# Speed: 1.6ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 448x640 (no detections), 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 0.3ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x640 1 Sai_gon, 7.9ms
# Speed: 1.7ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 448x640 1 Strongbow, 7 Sai_gons, 8.6ms
# Speed: 1.2ms preprocess, 8.6ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 (no detections), 7.9ms
# Speed: 1.7ms preprocess, 7.9ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 1 bia_333, 8.4ms
# Speed: 1.8ms preprocess, 8.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 448x640 4 Strongbows, 7.8ms
# Speed: 1.5ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 18 Heinekens, 13 Tigers, 1 Sai_gon, 7.7ms
# Speed: 1.7ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 31 Heinekens, 7.5ms
# Speed: 1.3ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x384 (no detections), 7.9ms
# Speed: 1.2ms preprocess, 7.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 448x640 9 Sai_gons, 7.8ms
# Speed: 1.3ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 3 bia_333s, 7.5ms
# Speed: 1.3ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 5 Tigers, 7.5ms
# Speed: 2.1ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 416x640 3 Sai_gons, 1 bia_333, 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 320x640 1 Heineken, 2 Larues, 1 Sai_gon, 8.0ms
# Speed: 0.8ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 640x640 1 Heineken, 8.4ms
# Speed: 1.7ms preprocess, 8.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 448x640 3 Tigers, 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 480x640 1 Tiger, 6 Larues, 7.9ms
# Speed: 1.6ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 1 Heineken, 2 Strongbows, 6 Sai_gons, 7.9ms
# Speed: 1.7ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x480 (no detections), 7.7ms
# Speed: 1.7ms preprocess, 7.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x640 1 Strongbow, 7.9ms
# Speed: 1.9ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 1 bia_333, 7.8ms
# Speed: 1.5ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 480x640 27 Heinekens, 5 Bia_Viets, 8.6ms
# Speed: 1.4ms preprocess, 8.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.6ms
# Speed: 1.7ms preprocess, 7.6ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 1 Sai_gon, 9.4ms
# Speed: 1.3ms preprocess, 9.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 26 Heinekens, 7.8ms
# Speed: 1.5ms preprocess, 7.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 1 Sai_gon, 9.3ms
# Speed: 1.7ms preprocess, 9.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# libpng warning: iCCP: known incorrect sRGB profile
# 0: 640x480 2 Bia_Viets, 2 Sai_gons, 8.5ms
# Speed: 1.7ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x640 1 Strongbow, 8.9ms
# Speed: 2.1ms preprocess, 8.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 8.3ms
# Speed: 1.8ms preprocess, 8.3ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 4 bia_333s, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 3 Bia_Viets, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x480 8 Tigers, 8.7ms
# Speed: 1.5ms preprocess, 8.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 640x416 1 Sai_gon, 1 bia_333, 9.3ms
# Speed: 1.1ms preprocess, 9.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 480x640 2 Sai_gons, 23.3ms
# Speed: 2.2ms preprocess, 23.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x640 4 Strongbows, 8.6ms
# Speed: 1.5ms preprocess, 8.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 Strongbows, 9.4ms
# Speed: 1.0ms preprocess, 9.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 2 Sai_gons, 8.3ms
# Speed: 1.4ms preprocess, 8.3ms inference, 0.7ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 480x640 1 Strongbow, 9.3ms
# Speed: 1.4ms preprocess, 9.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 352x640 5 Strongbows, 9.9ms
# Speed: 1.1ms preprocess, 9.9ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 448x640 14 Tigers, 8.0ms
# Speed: 1.3ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 640x640 78 Heinekens, 5 Edelweisss, 8.1ms
# Speed: 1.8ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 416x640 1 Sai_gon, 8.1ms
# Speed: 1.2ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
# Hoàn thành việc crop và lưu ảnh.
